# %% [markdown]
# # Introduction to Probabilistic Graphical Models
# ## Mini Project
# ### Author: Xiang Yu, Email: shawnxiangyu@yahoo.com

# %% [markdown]
# #### Question 1.1

# %% [markdown]
# #### Question 1.2

# %% [markdown]
# Non-negative matrix factorization (NMF or NNMF), also non-negative matrix approximation is a group of algorithms in multivariate analysis and linear algebra where a matrix V is factorized into (usually) two matrices W and H, with the property that all three matrices have no negative elements. (source: wiki)
#
# NMF is used for feature extraction and is generally seen to be useful when there are many attributes, particularly when the attributes are ambiguous or are not strong predictors. By combining attributes NMF can display patterns, topics, or themes which have importance. NMF method is found in many applications, for this project we apply NMF to the face images.
#
#
# #### Goal: Find $W, H$ such that for a given $V$, $ V \approx W H$
# Given an $F \times N$ matrix $V$ with nonnegative elements, we wish to
# find nonnegative, rank-$K$ matrices $W$ ($F \times K$) and $H$ ($K
# \times N$) such that $$ V \approx W H $$
#
# or more precisely:
# $$ V_{fn} \approx \sum_{k = 1}^{K} W_{fk} H_{kn}$$
#
# The goal can be achieved by solving the following optimization problem:
# $$ (W, H) \in  arg \max_{W,\  H \geq 0} P(V; W, H) $$
#
# #### E-step 1: E function overview
#
# In the following calculation, when no confusion occurs, we use $Z$ to denote the parameters $(W, H)$,i.e. $Z = WH$, then
#
# $$ P(V; W, H) = P(V; Z) = P(V|Z) $$
#
# We could solve the optimization problem with Expectation–maximization(EM) algorithm taught during the lecture.
#
# Here we introduce a latent variable $S$ with the following properties:
#
# $$q(S) > 0,\  \sum_S q(S) = 1 $$
#
# Then the original optimization problem will be equivilant to
# $$ arg \max_{W,\  H \geq 0} P(V; W, H)   \propto  arg \max_{Z \geq 0} \log P(V|Z)$$
#
# And
# \begin{align}
# \log P(V|Z)
# &=  \log \sum_S P(V, S|Z) \\
# & = \log \sum_S P(V, S|Z) \frac{q(S)}{q(S)} \\
# & = \log \sum_S \frac{P(V, S|Z)}{q(S)} q(S) \\
# & = \log \mathbb{E}[\frac{P(V, S|Z)}{q(S)}]_{q(S)} \\
# & \geq \mathbb{E} \log [\frac{P(V, S|Z)}{q(S)}]_{q(S)}
# \end{align}
#
#
# We have proved in the lecture for EM algorithm that:
#
# $$ q(S) = P(S|V, Z)$$
#
#
#
# Then we have
# \begin{align}
# \log P(V|Z) \geq \mathbb{E} \log [\frac{P(V, S|Z)}{q(S)}]_{q(S)}
# &  = \sum q(S) \log \frac{P(V, S|Z)}{q(S)} \\
# &  = \sum q(S) \log {P(V, S|Z)} - \sum q(S) \log q(S) \\
# &  = \mathbb{E} [\log P(V, S|Z)]_{q(S)} - \mathbb{E} [\log q(S)]_{q(S)} \\
# &  = \mathbb{E} [\log P(V, S|Z)]_{P(S|V, Z^{t})} - \mathbb{E} [\log P(S|V, Z^{t})]_{P(S|V, Z^{t})}
# \end{align}
#
# We need to maximize the right side of above equaiton with respect to the parameter $Z = (W, H)$.
# Then,
#
# $$
# arg \max_{Z \geq 0} \mathbb{E} [\log P(V, S|Z)]_{P(S|V, Z^{t})} - \mathbb{E} [\log P(S|V, Z^{t})]_{P(S|V, Z^{t})}  \propto arg \max_{Z \geq 0} \mathbb{E} [\log P(V, S|Z)]_{P(S|V, Z^{t})}
# $$
#
#
# Then we have the E-step function to be maximized as follows:
# $$L(Z) = \mathbb{E} [\log P(V, S|Z)]_{P(S|V, Z^{t})}$$

# %% [markdown]
# In order to calculate $L(Z)$, we should calculate the terms in $L(Z)$ first. I.e. the following two terms:
# -  $P(S|V, Z^{t})$
# - $\log P(V, S|Z)$
#
# #### E-step 2: term $P(S|V, Z^{t})$
#
# We have:
# $$P(S|V, Z^{t}) = \frac{P(S, V, Z^{t})}{P(V, Z^{t}))} = \frac{P(S, V|Z^{t})}{P(V|Z^{t})}$$
#
# And according to the directed graph model in Question 1.1, we have:
#
# $$P(S, V|Z^{t}) = P(V|S)P(S|Z^{t})$$
#
# Therefore, we have:
# $$P(S|V, Z^{t}) = \frac{P(V|S)P(S|Z^{t})}{P(V|Z^{t})}$$
#
#
# Notice: the $S$ is introduced to have the following properties:
#
# $$V_{fn} = \sum_{k = 1}^{K} S_{f\_k\_n}, \  S_{f\_k\_n} \sim \operatorname{Poisson}(S_{f\_k\_n}; W_{fk} H_{kn}) $$
#
# When no confusion occurs, we write:
# $$S_{f\_k\_n}: = S_k, \ and \  W_{fk} H_{kn}: = Z_{f\_k\_n} := Z_k$$
#
#
# Thus:
#
# $$V_{fn} = \sum_{k = 1}^{K} S_k, \  S_k\sim \operatorname{Poisson}(S_k; Z_k) $$
#
# From Poission distribution we know that for any $a, b$, we have:
# $$\operatorname{Poisson}(a; b) = P(a|b) = \exp (a \log b - b - \log \Gamma (a + 1)) $$
#
#
# Then:
# $$P(S_k|Z_k^{t}) = \operatorname{Poisson}(S_k; Z_k^{t}) = \exp (S_k \log Z_k^{t} - Z_k^{t} - \log \Gamma (S_k + 1))  $$
#
# With $V_{fn} = \sum_{k = 1}^{K} S_k$ and $S_k\sim \operatorname{Poisson}(S_k; Z_k) $, and according to the well-know superposition property of Poisson random variables. we have:
#
#
# $$P(V_{fn}|Z^{t}) \sim \operatorname{Poisson}(V_{fn}; \sum_{k = 1}^{K}  Z_k^t)$$
#
# We also have:
# $$P(V_{fn}|S) = P(V_{fn}|S_{1:K}) = \delta (V_{fn}- \sum_{k = 1}^{K} S_k)$$
# where:
# $$
# \delta(x) = \{
# \begin{array}{ll}
#   1, \ if \ x = 0 \\
#   0, \ otherwise
# \end{array}
# $$
#
# With the given information and the lecture notes, we know that $P(S_{1:K}|V_{fn})$ follows a multinomial distribution, with
#
# $$P(S_{1:K}|V_{fn}) =\delta (V_{fn}- \sum_{k = 1}^{K} S_k) \frac{V_{fn}!}{S_1!S_2!...S_K!}(\frac{Z_1}{\sum_k Z_k})^{S_1}...(\frac{Z_K}{\sum_k Z_k})^{S_K}$$

# %% [markdown]
# Then:
# $$\log P(S|V, Z^{t}) = \log \frac{P(V|S)P(S|Z^{t})}{P(V|Z^{t})} = \log P(V|S)P(S|Z^{t}) - \log P(V|Z^{t}) $$
#
# Where
# \begin{align}
# \log P(V|Z^{t})
# & = \log \Pi_{f,\  n} \operatorname{Poisson}(V_{fn}; \sum_{k = 1}^{K}  Z_k^t) \\
# & = \sum_{f,\  n} \log \operatorname{Poisson}(V_{fn}; \sum_{k = 1}^{K}  Z_k^t) \\
# &= \sum_{f,\  n} (V_{fn} \log Z_k^{t} - Z_k^{t} - \log \Gamma (V_{fn} + 1))
# \end{align}
#
# and
# \begin{align}
# \log P(V|S)P(S|Z^{t})
# & = \log \Pi_{f,\  n} [P(V_{fn}|S_{1:K}) \Pi_{k = 1}^{K} P(S_k|Z^{t})] \\
# & = \sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} \log \operatorname{Poisson}(S_k; Z_k^{t})] \\
# &= \sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} (S_k \log Z_k^{t} - Z_k^{t} - \log \Gamma (S_k + 1))]
# \end{align}

# %% [markdown]
# #### E-step 3: term $\log P(V, S|Z)$
# As shown above, we have:
#
# $$\log P(V, S|Z) = \log P(V|S)P(S|Z)$$
#
# Then we have:
# \begin{align}
# \log P(V, S|Z)
# & = \log P(V|S)P(S|Z) \\
# & = \log \Pi_{f,\  n} [P(V_{fn}|S_{1:K}) \Pi_{k = 1}^{K} P(S_k|Z)] \\
# & = \sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} \log \operatorname{Poisson}(S_k; Z_k)] \\
# &= \sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} (S_k \log Z_k - Z_k - \log \Gamma (S_k + 1))]
# \end{align}
#
#
# #### E-step 4: E-function in detail:
# We have the expectation function as follows:
# $$L(Z) = \mathbb{E} [\log P(V, S|Z)]_{P(S|V, Z^{t})}$$
#
# Denote: $P(S|V, Z^{t}): = \gamma^t$, then:
# \begin{align}
# L(Z)
# & = \mathbb{E} [\log P(V, S|Z)]_{\gamma^t} \\
# & = \mathbb{E}(\sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} (S_k \log Z_k - Z_k - \log \Gamma (S_k + 1))])_{\gamma^t} \\
# & = \sum_{f,\  n} ( \mathbb{E}[\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k)]_{\gamma^t} + \mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k - \log \Gamma (S_k + 1))]_{\gamma^t}) \\
# & = Constant1 + \sum_{f,\  n}(\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t} - \mathbb{E}[ \log \Gamma (S_k + 1)]_{\gamma^t}) \\
# & =  Constant1 + \sum_{f,\  n}\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t} - Constant2
# \end{align}
#
# Here, with $ Z^{t}$ given, the two terms: $\mathbb{E}[\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k)]_{\gamma^t} := Constant1$ and $\mathbb{E}[ \log \Gamma (S_k + 1)]_{\gamma^t}:=Constant2$ will be constant when the expectation is calculated with respect to $\gamma^t$ .
#
# Since the M-step is to maximize $L(Z)$, then
#
# $$Z^{t+1} = \arg \max_{Z \geq 0} L(Z) \propto  arg \max_{Z \geq 0} \sum_{f,\  n}\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t}$$
#
# Therefore, we could update the objective function $L(Z)$ as follows:
# \begin{align}
# L(Z)
# & = \sum_{f,\  n}\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t} \\
# & = \sum_{f,\  n}(\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k]_{\gamma^t} - \mathbb{E}[Z_k]_{\gamma^t})\\
# & = \sum_{f,\  n}(\sum_{k = 1}^{K} (\gamma^t S_k \log Z_k - Z_k)
# \end{align}

# %% [markdown]
# #### M-step 1:  objective function in the form of $W, H$
# We know that the optimal solution $Z^*$ of $\max_{Z \geq 0} L(Z)$ is the stationary point of $L(Z)$,i.e.
# $$\bigtriangledown L(Z^*) = 0$$
#
# We know that $Z = WH, Z_k = Z_{f\_k\_n}  = W_{fk} H_{kn}$, we would like to find out the update rule for $W, H$ seperately.
#
# We write $L(Z)$ and all the terms within here:
# $$L(Z) = \sum_{f,\  n}(\sum_{k = 1}^{K} (\gamma^t S_k \log Z_k - Z_k)$$
# We have $\gamma^t = P(S|V, Z^{t}) $ and
# \begin{align}
# \log \gamma^t
# & = \log P(S|V, Z^{t}) \\
# & = \log P(V|S)P(S|Z^{t}) - \log P(V|Z^{t}) \\
# & = \sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} (S_k \log Z_k^{t} - Z_k^{t} - \log \Gamma (S_k + 1))] - \sum_{f,\  n} (V_{fn} \log Z_k^{t} - Z_k^{t} - \log \Gamma (V_{fn} + 1))
# \end{align}
#
#
# We have
# $$V_{fn} = \sum_{k = 1}^{K} S_{f\_k\_n}, \  S_{f\_k\_n} \sim \operatorname{Poisson}(S_{f\_k\_n}; W_{fk} H_{kn}) $$
# We could simplify the term with $\gamma^t S_k$ here based on the properties of mutilnomial and Possion distribution:
# $$\gamma^t S_k = \mathbb{E}[S_k]_{\gamma^t} = V_{fn}P(S_k) = V_{fn} \frac{Z_k^t}{\sum_{k=1}^K Z_k^t} = V_{fn} \frac{W_{fk}^t H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}$$
#
#
# Then $L(Z)$ to be expressed with $W, H$ will be as follows:
#
# $$L(WH) = \sum_{f,\  n}(\sum_{k = 1}^{K} (V_{fn} \frac{W_{fk}^t H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t} \log (W_{fk} H_{kn}) - W_{fk} H_{kn})$$

# %% [markdown]
# #### M-step 2:  update rule of $W, H$
#
# \begin{align}
# \frac{\partial L}{\partial W_{fk}}
# & = \frac{\partial }{\partial W_{fk}} \sum_f \sum_n (\sum_{k = 1}^{K} \gamma^t S_k  \log (W_{fk} H_{kn}) - W_{fk} H_{kn}) \\
# & = \sum_n(\frac{\gamma^t S_k}{W_{fk}} - H_{kn}) \\
# & = - \sum_nH_{kn} +  \frac{\sum_n\gamma^t S_k}{W_{fk}} \\
# & = - \sum_nH_{kn} +  \frac{\sum_n(V_{fn} \frac{W_{fk}^t H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t})}{W_{fk}}
# \end{align}
#
#
# Then,
# \begin{align}
# W_{fk}^{t+1}
# & = \frac{\sum_n\gamma^t S_k}{\sum_nH_{kn}} \\
# & = \frac{\sum_nV_{fn} \frac{W_{fk}^t H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_nH_{kn}} \\
# & =  W_{fk}^t\frac{ \sum_n\frac{V_{fn}H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_nH_{kn}}
# \end{align}
#
# The calculaltion for $H_{kn}$ is quite similar, and we could get the update rule for $H_{kn}$ as follows:
# $$H_{kn}^{t+1} = H_{kn}^t \frac{ \sum_f\frac{W_{fk}^tV_{fn}}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_fW_{fk}^t}$$
#
# Finally, we have find the EM algorithm/formula for NMF problem.

# %%
# %matplotlib inline
import numpy as np
from scipy.linalg import norm
import matplotlib.pyplot as plt
import networkx as nx
import pyparsing
from IPython.display import Math
import copy
import math
from matplotlib.patches import Ellipse 
import scipy.io as sio
from numba import njit
from matplotlib import gridspec
from tqdm import tqdm
from numba import jit
import time

math_pi = math.pi

# %%
# read the raw data 
imgs_data = sio.loadmat('attfaces.mat')
V = imgs_data['V']

# %% [markdown]
# #### Code notations in function updateWH and their matching math terms:
#
# $$W_{fk}^{t+1} = W_{fk}^t\frac{ \sum_n\frac{V_{fn}H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_nH_{kn}}$$
#
# The code corresponding to the math terms are as follows:
# no: nominator, $$ no = \frac{no\_part\_no}{no\_part\_de} $$
# with no_part_no $= V_{fn}H_{kn}^t$, and no_part_de $= \sum_{k=1}^K W_{fk}^t H_{kn}^t$ and de = $\sum_nH_{kn}$,
# Then:
# $$W_{fk}^{t+1}  = W_{fk}^t \frac{\sum no}{de} $$
#
# The $H$ part is simliar.

# %%
# formula for updating W, and H
# @jit()
def updateW(V, W, H): 
    no_part_no = np.einsum('ij,kj->ijk', V, H)
    no_part_de = np.matmul(W, H)
    no = no_part_no / no_part_de[:,:, np.newaxis]
    de = np.sum(H, axis=1) 
    Wp = W * np.sum(no, axis=1) / de[np.newaxis,:]
    
    return Wp

# @jit()
def updateH(V, W, H): 
    no_part_no = np.einsum('ij,ik->ikj', V, W)
    no_part_de = np.matmul(W, H)
    no = no_part_no / no_part_de[:,np.newaxis,:]
    de = np.sum(W, axis=0) 
    Hp = H * np.sum(no, axis=0) / de[:,np.newaxis]
    
    return Hp


def updateWH(nr_iter, W_init, H_init, threshold=1e-6): 
    Wt = W_init.copy()
    Ht = H_init.copy()
    Diffs = np.zeros((nr_iter + 1,1))
    Diffs[0] = norm(V - Wt.dot(Ht)) # use Euclidean distance to measure the approximation
    
    max_iter = 5000

    
    for i in np.arange(nr_iter):   
#         # update W
#         no_part_no = np.einsum('ij,kj->ijk', V, Ht)
#         no_part_de = np.matmul(Wt, Ht)
#         no = no_part_no / no_part_de[:,:, np.newaxis]
#         de = np.sum(Ht, axis=1) 
#         Wtp = Wt * np.sum(no, axis=1) / de[np.newaxis,:]
        
        Wtp = updateW(V, Wt, Ht)       
        Htp = updateH(V, Wtp, Ht)

#         # update H
#         no_part_no = np.einsum('ij,ik->ikj', V, Wtp)
#         no_part_de = np.matmul(Wtp, Ht)
#         no = no_part_no / no_part_de[:,np.newaxis,:]
#         de = np.sum(Wtp, axis=0) 
#         Htp = Ht * np.sum(no, axis=0) / de[:,np.newaxis]

        
        Wt = Wtp.copy()
        Ht = Htp.copy()

        Diffs[i+1] = norm(V - Wt.dot(Ht))
        
        if np.abs(Diffs[i+1] - Diffs[i]) / Diffs[i+1] < threshold or i > max_iter: 
            break
        
    return Diffs, Wt, Ht

# %%
@jit()
def updateWH2(nr_iter, W_init, H_init, threshold=1e-6): 
    Wt = W_init.copy()
    Ht = H_init.copy()
    Diffs = np.zeros((nr_iter + 1,1))
    Diffs[0] = norm(V - Wt.dot(Ht)) # use Euclidean distance to measure the approximation
    
    max_iter = 5000

    
    for i in np.arange(nr_iter):   
        # update W
        no_part_no = np.einsum('ij,kj->ijk', V, Ht)
        no_part_de = np.matmul(Wt, Ht)
        no = no_part_no / no_part_de[:,:, np.newaxis]
        de = np.sum(Ht, axis=1) 
        Wtp = Wt * np.sum(no, axis=1) / de[np.newaxis,:]
        
#         Wtp = updateW(V, Wt, Ht)       
#         Htp = updateH(V, Wtp, Ht)

        # update H
        no_part_no = np.einsum('ij,ik->ikj', V, Wtp)
        no_part_de = np.matmul(Wtp, Ht)
        no = no_part_no / no_part_de[:,np.newaxis,:]
        de = np.sum(Wtp, axis=0) 
        Htp = Ht * np.sum(no, axis=0) / de[:,np.newaxis]

        
        Wt = Wtp.copy()
        Ht = Htp.copy()

        Diffs[i+1] = norm(V - Wt.dot(Ht))
        
        if np.abs(Diffs[i+1] - Diffs[i]) / Diffs[i+1] < threshold or i > max_iter: 
            break
        
    return Diffs, Wt, Ht

# %%
# %load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython
# import numpy as np
# cimport numpy as np
# cimport cython
#
#
# def updateWH3(nr_iter, V, W_init, H_init, threshold=1e-6):
#     Wt = W_init.copy()
#     Ht = H_init.copy()
#     Diffs = np.zeros((nr_iter + 1,1))
#     Diffs[0] = np.linalg.norm(V - Wt.dot(Ht)) # use Euclidean distance to measure the approximation
#
#     max_iter = 5000
#
#
#     for i in np.arange(nr_iter):
#
#         # update W
#         # no_part_no = np.einsum('ij,kj->ijk', V, Ht)
#        # no_part_de = np.matmul(Wt, Ht)
# #         no = np.einsum('ij,kj->ijk', V, Ht) / np.matmul(Wt, Ht)[:,:, np.newaxis]
#
#
# #         de = np.sum(Ht, axis=1)
#         Wtp = Wt * np.sum(np.einsum('ij,kj->ijk', V, Ht) / np.matmul(Wt, Ht)[:,:, np.newaxis], axis=1) / np.sum(Ht, axis=1)[np.newaxis,:]
#
# #         Wtp = updateW(V, Wt, Ht)
# #         Htp = updateH(V, Wtp, Ht)
#
#         # update H
#         no_part_no = np.einsum('ij,ik->ikj', V, Wtp)
#         no_part_de = np.matmul(Wtp, Ht)
#         no = no_part_no / no_part_de[:,np.newaxis,:]
#         de = np.sum(Wtp, axis=0)
#         Htp = Ht * np.sum(no, axis=0) / de[:,np.newaxis]
#
#
#         Wt = Wtp.copy()
#         Ht = Htp.copy()
#
#         Diffs[i+1] = np.linalg.norm(V - Wt.dot(Ht))
#
#         if np.abs(Diffs[i+1] - Diffs[i]) / Diffs[i+1] < threshold or i > max_iter:
#             break
#
#     return Diffs, Wt, Ht

# %%
@njit
def updateWH4(nr_iter, Wt, Ht, threshold=1e-6): 
#     Wt = W_init.copy()
#     Ht = H_init.copy()
    Diffs = np.zeros((nr_iter + 1,1))
    Diffs[0] = np.linalg.norm(V - Wt.dot(Ht)) # use Euclidean distance to measure the approximation
    
    max_iter = 5000

    
    for i in np.arange(nr_iter): 
        no_part_no = np.einsum('ij,kj->ijk', V, Ht)
        no_part_de = np.matmul(Wt, Ht)
        no = no_part_no / no_part_de[:,:, np.newaxis]
        de = np.sum(Ht, axis=1) 
        Wtp = Wt * np.sum(no, axis=1) / de[np.newaxis,:]
        # update W
        # no_part_no = np.einsum('ij,kj->ijk', V, Ht)
       # no_part_de = np.matmul(Wt, Ht)
#         no = np.einsum('ij,kj->ijk', V, Ht) / np.matmul(Wt, Ht)[:,:, np.newaxis]
        
        
#         de = np.sum(Ht, axis=1) 
        #Wtp = Wt * np.sum(np.einsum('ij,kj->ijk', V, Ht) / np.matmul(Wt, Ht)[:,:, np.newaxis], axis=1) / np.sum(Ht, axis=1)[np.newaxis,:]
        
#         Wtp = updateW(V, Wt, Ht)       
#         Htp = updateH(V, Wtp, Ht)

        # update H
        no_part_no = np.einsum('ij,ik->ikj', V, Wtp)
        no_part_de = np.matmul(Wtp, Ht)
        no = no_part_no / no_part_de[:,np.newaxis,:]
        de = np.sum(Wtp, axis=0) 
        Htp = Ht * np.sum(no, axis=0) / de[:,np.newaxis]

        
        Wt = Wtp.copy()
        Ht = Htp.copy()

        Diffs[i+1] = np.linalg.norm(V - Wt.dot(Ht))
        
        if np.abs(Diffs[i+1] - Diffs[i]) / Diffs[i+1] < threshold or i > max_iter: 
            break
        
    return Diffs, Wt, Ht

# %%
# %%cython
# def test():
#     return 1

# %%
# initialize the W, H from gamma distribution
def init_para(alpha, beta, size): 
    return np.random.gamma(alpha, beta, size)

# initialize one set of inputs for EM algorithm
alpha_w = 1
alpha_h = 1
beta_w = 1
beta_h = 1

size = np.shape(V)
K = 25
F = size[0]
N = size[1]

W_init = init_para(alpha_w, 1 / beta_w, (F, K))
H_init = init_para(alpha_h, 1 / beta_h, (K, N))

nr_iter = 20
# run EM algorithm with the intilized data 
# t = time.time()

# print ("%.3f" % (time.time()-t))

# %%
# %%time
Diffs, W, H = updateWH(nr_iter, W_init, H_init)
# Out:
# CPU times: user 29.6 s, sys: 28.1 s, total: 57.7 s
# Wall time: 40.1 s

# %%
t = time.time()
Diffs, W, H = updateWH(nr_iter, W_init, H_init)
print ("%.3f" % (time.time()-t))
# Out:
# 39.058

# %%
t = time.time()
Diffs, W, H = updateWH2(nr_iter, W_init, H_init)
print ("%.3f" % (time.time()-t))
# Out:
# 39.439

# %%
t = time.time()
Diffs, W, H = updateWH3(nr_iter, V, W_init, H_init)    
print ("%.3f" % (time.time()-t))
# Out:
# 37.911

# %%
t = time.time()
Diffs, W, H = updateWH4(nr_iter,  W_init, H_init)    
print ("%.3f" % (time.time()-t))
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-36-8f0df7e2703e> in <module>()
#       1 t = time.time()
# ----> 2 Diffs, W, H = updateWH4(nr_iter,  W_init, H_init)
#       3 print ("%.3f" % (time.time()-t))
#
# /usr/local/lib/python3.6/dist-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     346                 e.patch_message(msg)
#     347
# --> 348             error_rewrite(e, 'typing')
#     349         except errors.UnsupportedError as e:
#     350             # Something unsupported is present in the user code, add help info
#
# /usr/local/lib/python3.6/dist-packages/numba/dispatcher.py in error_rewrite(e, issue_type)
#     313                 raise e
#     314             else:
# --> 315                 reraise(type(e), e, None)
#     316
#     317         argtypes = []
#
# /usr/local/lib/python3.6/dist-packages/numba/six.py in reraise(tp, value, tb)
#     656             value = tp()
#     657         if value.__traceback__ is not tb:
# --> 658             raise value.with_traceback(tb)
#     659         raise value
#     660
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Use of unsupported NumPy function 'numpy.einsum' or unsupported use of the function.
#
# File "<ipython-input-35-3b89721a3f45>", line 12:
# def updateWH4(nr_iter, Wt, Ht, threshold=1e-6):
#     <source elided>
#     for i in np.arange(nr_iter):
#         no_part_no = np.einsum('ij,kj->ijk', V, Ht)
#         ^
#
# [1] During: typing of get attribute at <ipython-input-35-3b89721a3f45> (12)
#
# File "<ipython-input-35-3b89721a3f45>", line 12:
# def updateWH4(nr_iter, Wt, Ht, threshold=1e-6):
#     <source elided>
#     for i in np.arange(nr_iter):
#         no_part_no = np.einsum('ij,kj->ijk', V, Ht)
#         ^
#
# This is not usually a problem with Numba itself but instead often caused by
# the use of unsupported features or an issue in resolving types.
#
# To see Python/NumPy features supported by the latest release of Numba visit:
# http://numba.pydata.org/numba-doc/dev/reference/pysupported.html
# and
# http://numba.pydata.org/numba-doc/dev/reference/numpysupported.html
#
# For more information about typing errors and how to debug them visit:
# http://numba.pydata.org/numba-doc/latest/user/troubleshoot.html#my-code-doesn-t-compile
#
# If you think your code should work with Numba, please report the error message
# and traceback, along with a minimal reproducer at:
# https://github.com/numba/numba/issues/new

# %%
9.5 ,10.6, 9.5

# %%
def plot_img(imgs, nr_rows, nr_cols, titlestr, grayscale=True): 
    
    fig = plt.figure(figsize = (15,15))    
    gs1 = gridspec.GridSpec(nr_rows, 1)
    gs1.update(wspace=0, hspace=0) # set the spacing between axes.
    cmap = 'None' if grayscale == False else 'gray'
    img_nr = 0 
    
    for rowi in np.arange(nr_rows):     
        img_ij = []
        
        for colj in np.arange(nr_cols):                  
            img_j = imgs[:,:,img_nr]
            if colj > 0: 
                img_ij = np.concatenate((img_ij, img_j))
            else: 
                img_ij = img_j
            img_nr += 1
        
        ax1 = plt.subplot(gs1[rowi])
        plt.axis('on')
        plt.imshow(img_ij.T, cmap=cmap)
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])
        ax1.set_aspect('equal')
        plt.subplots_adjust(wspace=0, hspace=0) 

    fig.suptitle(titlestr)
    fig.subplots_adjust(top=0.95)
    plt.show()

# %%
# plot W
W_imgs = W.reshape((92, 112, K))
plot_img(W_imgs, 5, 5, 'Visualize W')

# %%
# plot the convergence graph
plt.plot(np.arange(nr_iter+1), Diffs)
plt.xlabel('Nr_interations')
plt.ylabel('Residual errors')
plt.title('Euclidean distance between V and V_new')
plt.show()

# %%
# plot several origial pictures and new pictures from V and NewV
NewV = W.dot(H)
nr_rows = 3
nr_cols = nr_rows
NrP = nr_rows ** 2 

V_NrP = V[:,:NrP].reshape((92, 112, NrP))
NewV_NrP = NewV[:,:NrP].reshape((92, 112, NrP))
plot_img(V_NrP, nr_rows, nr_cols, 'Plot original ' + str(NrP) +' pictures')
plot_img(NewV_NrP, nr_rows, nr_cols, 'Plot new ' + str(NrP) +' pictures')

# %%
alpha_w = 1
alpha_h = 1
beta_w = 1
beta_h = 1


size = np.shape(imgs)
K = 25
F = size[0]
N = size[1]

W_init = init_para(alpha_w, 1 / beta_w, (F, K))
H_init = init_para(alpha_h, 1 / beta_h, (K, N))

# %%
# New_V.shape
# V_or1 = V[:,0].reshape((92, 112))
# plt.imshow(V_or1, cmap=None)
# #cmap = 'gray_r'

# %%
import multiprocessing



updateWH(nr_iter, W_init, H_init)

Input = [[nr_iter, W_init, H_init], ]

for i in range(5):
    p = multiprocessing.Process(target=updateWH, args=(i,))
    jobs.append(p)
    p.start()

# %%
# nr_iter = 100
# W = W_init.copy()
# H = H_init.copy()
# Diffs = []
# Diffs.append(norm(V - W.dot(H)))
# for i in np.arange(nr_iter): 
    
#     # update W
#     no_part_no = np.einsum('ij,kj->ijk', V, H)
#     no_part_de = np.matmul(W, H)
#     no = no_part_no / no_part_de[:,:, np.newaxis]
#     de = np.sum(H, axis=1) 
#     W = W * np.sum(no, axis=1) / de[np.newaxis,:]
    
#     # update H
#     no_part_no = np.einsum('ij,ik->ikj', V, W)
#     no_part_de = np.matmul(W, H)
#     no = no_part_no / no_part_de[:,np.newaxis,:]
#     de = np.sum(W, axis=0) 
#     H = H * np.sum(no, axis=0) / de[:,np.newaxis]
    
#     Diffs.append(norm(V - W.dot(H)))

# %%
# print(Diffs)
# plt.plot(np.arange(nr_iter+1), Diffs)

# %%
# def plot_img(imgs, nr_rows, nr_cols, titlestr): 
    
#     fig, axs = plt.subplots(nrows=nr_rows, ncols=nr_cols, figsize=(15,20),
#                         subplot_kw={'xticks': [], 'yticks': []})
    
# #     wid_ratio = np.ones(nr_rows)
# #     gs = gridspec.GridSpec(nr_rows, nr_cols, width_ratios=wid_ratio,
# #          wspace=0.0, hspace=0.0, top=0.95, bottom=0.05, left=0.17, right=0.845) 
    
#     img_nr = 0 
#     #plt.figure(figsize=(15,20))
#     for rowi in np.arange(nr_rows): 
        
#         for colj in np.arange(nr_cols): 
            
#             #fig, ax = plt.subplots(nr_rows, nr_cols, img_nr + 1)
#             ax = axs.flat[img_nr]
#             img_ij = imgs[img_nr].T 
#             ax.imshow(img_ij, cmap='gray')
#             img_nr += 1
#             ax.set_xticklabels([])
#             ax.set_yticklabels([])
#             #plt.subplots_adjust(wspace=0, hspace=0)   
#     #plt.suptitle(titlestr)  
#     fig.subplots_adjust(wspace=0, hspace=0)
#     fig.suptitle(titlestr)
#     fig.subplots_adjust(top=0.98)
#     #plt.tight_layout()
#     #plt.subplots_adjust(wspace=0, hspace=0)
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec

# plt.figure(figsize = (4,4))
# gs1 = gridspec.GridSpec(4, 4)
# gs1.update(wspace=0.025, hspace=0.05) # set the spacing between axes. 

# for i in range(16):
#    # i = i + 1 # grid spec indexes from 0
#     ax1 = plt.subplot(gs1[i])
#     plt.axis('on')
#     ax1.set_xticklabels([])
#     ax1.set_yticklabels([])
#     ax1.set_aspect('equal')
#     plt.subp

# plt.show()

# %%
# def plot_img(imgs, nr_rows, nr_cols, titlestr): 
    
# #     fig, axs = plt.subplots(nrows=nr_rows, ncols=nr_cols, figsize=(15,20),
# #                         subplot_kw={'xticks': [], 'yticks': []})
#     fig = plt.figure(figsize = (15,15))    
#     gs1 = gridspec.GridSpec(nr_rows, 1)
#     gs1.update(wspace=0, hspace=0) # set the spacing between axes. 
    
#     img_nr = 0 
#     #plt.figure(figsize=(15,20))
#     for rowi in np.arange(nr_rows): 
        
#         img_ij = []
        
#         for colj in np.arange(nr_cols): 
            
#             #fig, ax = plt.subplots(nr_rows, nr_cols, img_nr + 1)
            
            
#             img_j = imgs[img_nr]
#             if colj > 0: 
#                 img_ij = np.concatenate((img_ij, img_j))
#             else: 
#                 img_ij = img_j
            
  
#             img_nr += 1
        
#         ax1 = plt.subplot(gs1[rowi])
#         plt.axis('on')
#         plt.imshow(img_ij.T, cmap='gray')
#         ax1.set_xticklabels([])
#         ax1.set_yticklabels([])
#         ax1.set_aspect('equal')


#         #plt.subp
#         plt.subplots_adjust(wspace=0, hspace=0) 
# #             ax = axs.flat[img_nr]
# #             img_ij = imgs[img_nr].T 
# #             ax.imshow(img_ij, cmap='gray')
# #             img_nr += 1
# #             ax.set_xticklabels([])
# #             ax.set_yticklabels([])
# #             #plt.subplots_adjust(wspace=0, hspace=0)   
# #     plt.suptitle(titlestr)  
# #     fig.subplots_adjust(wspace=0, hspace=0)
#     fig.suptitle(titlestr)
#     fig.subplots_adjust(top=0.95)
# #     #plt.tight_layout()
#     #plt.subplots_adjust(wspace=0, hspace=0)
#     plt.show()

# %%
# plot_img(w_imgs, 5, 5, 'Visualize W')

# %%
# #  image[i*im_h:(i+1)*im_h, j*im_w:(j+1)*im_w] = new_W[:,:,i*n_rows+j]
# img_nr = 0    
# img_j = w_imgs[img_nr].T  
# img_ij = []
# img_ij = img_j
# # img_ij = np.concatenate(img_ij, img_j)
# np.concatenate((img_ij, img_j))
# img_j.shape

# %%
# _,axs = plt.subplots(3,4, figsize=(15,15))
# for i in range(4):
#     show_image(Ws[i],5,5,ax= axs[0][i], inverse=True )

# for i in range(4):
#     X = np.multiply(np.array([W[:,i]]).T, H[:,1])
#     show_image(X,5,5,ax= axs[1][i], inverse=True )
#     axs[2][i].imshow(X.sum(axis=1).reshape(92,112).T, cmap='gray_r')

# %%
# w_imgs
# img_ij = w_imgs[0]
# #print(img_ij )
# img_ij.shape
# plt.imshow(img_ij)

# fig, axs = plt.subplots(nrows=3, ncols=6, figsize=(15,20),
#                      data:image/png;base64,...   subplot_kw={'xticks': [], 'yticks': []})

# fig.subplots_adjust(left=0.03, right=0.97, hspace=0.3, wspace=0.05)

# for ax, interp_method in zip(axs.flat, methods):
#     ax.imshow(grid, interpolation=interp_method, cmap='viridis')
#     ax.set_title(str(interp_method))

# %%
# def show_image(V,n_rows, n_cols, im_h=112,im_w=92, ax=None, inverse = False ):
#     '''
#     V : The image you want to show
#     '''
#     cmap = 'gray_r' if inverse else 'gray'
#     new_W = np.apply_along_axis(lambda x: x.reshape(im_w,im_h).T,axis=0,arr=V )
#     image = np.zeros((im_h*n_rows,im_w*n_cols))
#     for i in range(n_rows):
#         for j in range(n_rows):
#             image[i*im_h:(i+1)*im_h, j*im_w:(j+1)*im_w] = new_W[:,:,i*n_rows+j]
#     if ax == None:
#         plt.figure(figsize=(15,20))
#         ax = plt.gca()
#     ax.imshow(image, cmap=cmap)

# %%
# show_image(W,5, 5)

# %%
# _,axs = plt.subplots(3,4, figsize=(15,15))
# for i in range(4):
#     show_image(Ws[i],5,5,ax= axs[0][i], inverse=True )

# for i in range(4):
#     X = np.multiply(np.array([W[:,i]]).T, H[:,1])
#     show_image(X,5,5,ax= axs[1][i], inverse=True )
#     axs[2][i].imshow(X.sum(axis=1).reshape(92,112).T, cmap='gray_r')

# %%
# W = W_init.copy()
# H = H_init.copy()
# Diffs = norm(V - W.dot(H))

# %%
# no_part_no = np.einsum('ij,ik->ikj', V, W)
# no_part_de = np.matmul(W, H)
# no = no_part_no / no_part_de[:,np.newaxis,:]
# de = np.sum(W, axis=0) 
# H = H * np.sum(no, axis=0) / de[:,np.newaxis]

# %% [markdown]
# $$H_{kn}^{t+1} = \frac{H_{kn}^t \sum_f\frac{W_{fk}^tV_{fn}}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_fW_{fk}^t}$$

# %%
# de = np.sum(W, axis=0) 
# de.shape
# Out:
# (25,)

# %%
# # update rule for one row

# f = 1
# #W_f_K_H_K_N  =  np.sum(H.T * W[f,:],axis=0)
# W_f_K_H_K_N  =  np.matmul(W[f,:], H)
# V_f_N_H_K_N = H * V[f,:]

# Wf = W[f,:]

# no = np.sum(V_f_N_H_K_N / W_f_K_H_K_N, axis=1)  # K * 1
# de = np.sum(H, axis=1)   # K *1 

# Wf_new = np.multiply(Wf, np.multiply(no, 1./de))

# %%
# # now update rule for the whole matrix 

# no_part_no = np.einsum('ij,kj->ijk', V, H)
# no_part_de = np.matmul(W, H)

# no = no_part_no / no_part_de[:,:, np.newaxis]
# de = np.sum(H, axis=1) 

# multi = np.sum(no, axis=1) / de[np.newaxis,:]
# W = W * multi

# %%
# W = W_init.copy()
# H = H_init.copy()

# %% [markdown]
# \begin{align}
# W_{fk}^{t+1}
# & = \frac{\sum_n\gamma^t S_k}{\sum_nH_{kn}} \\
# & = \frac{\sum_nV_{fn} \frac{W_{fk}^t H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_nH_{kn}} \\
# & =  \frac{W_{fk}^t \sum_n\frac{V_{fn}H_{kn}^t}{\sum_{k=1}^K W_{fk}^t H_{kn}^t}}{\sum_nH_{kn}}
# \end{align}

# %%
# #### 2. Implement the EM algorithm for GMMs

# xs_nl = xs[:,:2]  # not labeled data
# xs_mean = np.mean(xs_nl, axis=0)
# xs_cov = np.cov(xs_nl.T)

# # initilize the parameters: set them to be equal
# xs = xs_nl.copy()
# ps = np.ones((3,1)) / K

# us = np.array([[0, 0.5], [1, 1.2], [2,0.1]]) # random choose some centers
# sigs = np.array([xs_cov, xs_cov, xs_cov])



# Nr_iter = 500
# log_liks = np.zeros((Nr_iter, 1))

# for it in np.arange(Nr_iter): 
    
#     gammas = cal_gammas(K, ps, us, sigs, xs)
    
#     log_lik = cal_loglik(K, ps, us, sigs, xs, gammas)
#     us_new, ps_new, sigs_new = update_para(gammas, K, ps, us, sigs, xs)
    
#     log_liks[it] = log_lik
    
#     title_str = "Nr_Iter: " + str(it) + ", Loglikelihood: " + str(round(log_lik, 2))
    
#     if it % 50 == 0: 
#         #fig, ax = plt.subplots(figsize=(8,8))
#         fig, ax = plt.subplots()
#         plt.scatter(x_g1[:,0], x_g1[:,1], c='b', label='First') 
#         plt.scatter(x_g2[:,0], x_g2[:,1], c='r', label='Second')
#         plt.scatter(x_g3[:,0], x_g3[:,1], c='k', label='Third') 
         
#         plot_contour(ax, us_new, sigs_new, colors)

#         ax.set_title("Iter: " + str(it) + ", Loglikelihood: " + str(np.round(log_lik, 2)))
#         plt.show()    
        
   
#     us = us_new.copy()
#     ps =  ps_new.copy()
#     sigs= sigs_new.copy()

# %% [markdown]
# \begin{align}
# \large \log P(V|Z) \geq \mathbb{E} \log [\frac{P(V, S|Z)}{q(S)}]_{q(S)}
# & \large = \sum q(S) \log \frac{P(V, S|Z)}{q(S)} \\
# & \large = \sum q(S) \log {P(V, S|Z)} - \sum q(S) \log q(S) \\
# & \large = \mathbb{E} [\log P(V, S|Z)]_{q(S)} - \mathbb{E} [\log q(S)]_{q(S)} \\
# & \large = \mathbb{E} [\log P(V, S|Z)]_{P(S|V, Z^{t})} - \mathbb{E} [\log P(S|V, Z^{t})]_{P(S|V, Z^{t})}
# \end{align}

# %% [markdown]
# Denote: $P(S|V, Z^{t}): = \gamma^t$, then:
# \begin{align}
# L(Z)
# & = \mathbb{E} [\log P(V, S|Z)]_{\gamma^t} \\
# & = \mathbb{E}(\sum_{f,\  n} [\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k) + \sum_{k = 1}^{K} (S_k \log Z_k - Z_k - \log \Gamma (S_k + 1))])_{\gamma^t} \\
# & = \sum_{f,\  n} ( \mathbb{E}[\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k)]_{\gamma^t} + \mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k - \log \Gamma (S_k + 1))]_{\gamma^t}) \\
# & = Constant1 + \sum_{f,\  n}(\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t} - \mathbb{E}[ \log \Gamma (S_k + 1)]_{\gamma^t}) \\
# & =  Constant1 + \sum_{f,\  n}\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t} - Constant2
# \end{align}
#
# Here, with $ Z^{t}$ given, the two terms: $\mathbb{E}[\log \delta (V_{fn}- \sum_{k = 1}^{K} S_k)]_{\gamma^t} := Constant1$ and $\mathbb{E}[ \log \Gamma (S_k + 1)]_{\gamma^t}:=Constant2$ will be constant when the expectation is calculated with respect to $\gamma^t$ .
#
# Since the M-step is to maximize $L(Z)$, then
#
# $$Z^{t+1} = \arg \max_{Z \geq 0} L(Z) \propto  arg \max_{Z \geq 0} \sum_{f,\  n}\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t}$$
#
# Therefore, we could update the objective function $L(Z)$ as follows:
# \begin{align}
# L(Z)
# & = \sum_{f,\  n}\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k - Z_k)]_{\gamma^t} \\
# & = \sum_{f,\  n}(\mathbb{E}[\sum_{k = 1}^{K} (S_k \log Z_k]_{\gamma^t} - \mathbb{E}[Z_k]_{\gamma^t})\\
# & = \sum_{f,\  n}(\sum_{k = 1}^{K} (S_k \log Z_k^{t}\gamma^t - Z_k^{t})
# \end{align}

# %%
# nr_iter = 10

# W = W_init.copy()
# H = H_init.copy()
# for i in np.arange(nr_iter): 
    
#     # if update only W_fk, then the nominator will be a single number
#     w_nominator = np.sum(V_f_{1:N} * H_k_{1:N}  / np.sum(W_fk * H_k_{1:N} ))
#     denominator = np.sum(H_k_{1:N})
#     W_fk = W_fk *  w_nominator / denominator
    
#     # now we update the f-th row of W: contains K numbers
#     # the w_nominator therefore now becomes a vector with K numbers
#     # np.sum(H[k,:]) will return different value for differnt k, in total K numbers
    
#     # W_f_ will contain K numbers, the product here then is element wise
#     # both w_nominnator and denominator will also contain K numbers
#     w_nominator = np.sum(V_f_{1:N}  * H_{1:K}_{1:N}  / np.sum(W_f_{1:K}  * H_{1:K}_{1:N}))
#     denominator = np.sum(H_{1:K}_{1:N})
    
#     no_part_de = np.sum(np.sum(H.T * W[f,:],axis=1))  # return N * 1
#     no_part_no = H * V[f,:]
#     no = np.sum(no_part_de/ no_part_no, axis=1)  # K * 1
#     de = np.sum(H, axis=1)  # axis=1: sum over columns, return vector of NrRows * 1, i.e. K * 1
    
#     W_f_ = W_f_ *

# %% [markdown]
# $$ V_{fn} \sim \operatorname{Poisson}(V_{fn}; \sum_{k = 1}^{K}  Z_k)$$
#
#  = \frac{P(V|S)P(S|Z^{t})}{\sum_S P(V|S)P(S|Z^{t})}
#
# $$
# \delta(t) = \Big\{ \frac34 \Bigg.
# $$
#
#
#
# $$P(V|S)P(S|Z^{t}) = \Pi_{f,\  n} P(V_{fn}|S)P(S|Z^{t})$$
#
# = \delta (V_{fn}- \sum_{k = 1}^{K} S_k)
#
#
# \begin{align}
# P(S|V, Z^{t})
# &=  \frac{P(S, V|Z^{t})}{P(V|Z^{t}))} \\
# & = \log \sum_S P(V, S|Z) \frac{q(S)}{q(S)} \\
#
# \end{align}
#
# & = \mathbb{E} \log [\frac{P(V, S|Z)}{q(S)}]_{q(S)}
#
# & = \log \E\[\frac{P(V, S|Z)}{P(S)}\]_{P(S)} \\
# & = \E\[\log \frac{P(V, S|Z)}{P(S)}\]_{P(S)
# P(V|Z) \frac
#
#
# \begin{align}
# \large \log(\sum\pi_j\mathcal{N_j})
#  &= \large log\sum_{i=1}^I \pi_j \kappa_j\exp(v_j) \\
#  & = \large \log\sum_{j=1}^I \pi_j\kappa_j \exp(v_j- V_{max} + V_{max}) \\
#   & = \large \log\sum_{j=1}^I \pi_j\kappa_j\exp(v_j- V_{max}) \exp(V_{max}) \\
#  & = \large V_{max} + \log\sum_{j=1}^I \pi_j\kappa_j\exp(v_j- V_{max})
# \end{align}
#
# So our goal is to find $W, H$ such that for a given $V$
# $$Err(W,H) = \min_{W,H}\|V-WH\|\,,$$
